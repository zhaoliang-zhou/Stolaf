# %% [markdown]
# # Two-Dimensional Random Walks
#
# Imagine you are standing at the origin of a plane. You choose randomly among the four directions up, down, left, and right. You then move one unit in the chosen direction. You repeat choosing one of the four directions and moving one unit in in that direction. Repeating again and again, your path in the plane is called a **two-dimensional random walk**.

# %% [markdown]
# ## Building a 2-D Random Walk
#
# First, we import some packages. We will use a 2-D matrix from the `numpy` package to store the locations visited on the walk.

# %%
import matplotlib.pyplot as plt
import random
import numpy

# %% [markdown]
# Write code to generate the random walk:

# %%
# define the possible moves at each step of the random walk
import matplotlib.pyplot as plt
import random
import numpy
dirs = numpy.array( [[0,1],[0,-1],[1,0],[-1,0]])
# define the number of steps to take
numStep = 1000

# set up a numpy 2-D array to store the locations visited.
locations = numpy.zeros((1,2))    # 1 row, 2 columns, entries set to zero

# take steps
for i in range(1,numStep):
    r = random.randrange(4)  ## select {0,1,2,3} at random 
    move = dirs[r]    ## random direction to move
    nextloc = locations[-1] + move  ## next location 
    locations = numpy.append(locations, [nextloc],axis=0) #append nextloc to loc

# %% [markdown]
# Now plot the random walk:

# %%
plt.plot(locations[:,0], locations[:,1], alpha = 0.6)

# %% [markdown]
# the 0 means the all the rows and 1 st column

# %% [markdown]
# ## When does the walk return to the origin?
#
# We noticed that 1-D random walks seem to revisit the origin somewhat frequently. Is the same true for 2-D random walks? Compute the average number of steps until a 2-D random walk returns to the origin.

# %%
numStep = 1000
dirs = numpy.array( [[0,1],[0,-1],[1,0],[-1,0]] )
locations = numpy.zeros((1,2))
while not numpy.array_equal(locations[-1],[0,0]):
          r = random.randrange(4)  
          move = dirs[r]   
          nextloc = locations[-1] + move  
          locations = numpy.append(locations, [nextloc],axis=0)

# %% [markdown]
# ## Diameter of a Random Walk
#
# Define the **width** of a 2-D random walk to be the maximum difference between any two $x$-coordinates attained by the walk. Similarly, define the **height** of the walk to be the maximum difference between any two $y$-coordinates.
#
# Define the **diameter** of a 2-D random walk to be the maximum of the width and height of the walk. (This isn't the only way to define the diameter of a 2-D random walk, but it's simple. Can you think of other ways?)
#
# What is the average diameter of a 2-D random walk after 100 steps? How does the diameter depend on the number of steps?

# %% [markdown]
# ## Distinct Points Visited
#
# How many distinct points (with integer coordinates only) does the random walk visit in its first 100 steps?
#
# How does the avereage number of distinct points visited depend on the number of steps?

# %% [markdown]
# ## Now investigate your own questions!
